# %%
import pandas as pd

weapons= pd.read_html('https://www.eurogamer.net/articles/2019-03-20-pubg-weapon-damage-stats-best-weapons-5414')
weapons
# Out:
# [   Weapon  Base Damage  Fire Rate  DPS  Time to Kill  Shots to Kill (Chest)  \
#  0     AWM          105       1.85   65          1.85                      2
#  1     M24           79       1.80   44          1.80                      2
#  2  Kar98k           75       1.90   39          3.80                      2
#  3   Win94           66       0.60  110          1.20                      2
#
#     Shots to Kill (Head)
#  0                     1
#  1                     1
#  2                     1
#  3                     2  ,
#      Weapon  Base Damage  Fire Rate  DPS  Time to Kill  Shots to Kill (Chest)  \
#  0     MK14           61       0.09  678         0.180                      3
#  1      SLR           58       0.10  580         0.200                      3
#  2      SKS           53       0.10  530         0.200                      3
#  3    QBU88           48       0.10  480         0.300                      4
#  4  Mini 14           46       0.10  460         0.300                      4
#  5      VSS           41       0.09  479         0.257                      4
#
#     Shots to Kill (Head)
#  0                     2
#  1                     2
#  2                     2
#  3                     2
#  4                     2
#  5                     2  ,
#           Weapon  Base Damage  Fire Rate    DPS  Time to Kill  \
#  0          M249           45      0.075  600.0         0.225
#  1         Groza           49      0.080  612.5         0.240
#  2    Beryl M762           47      0.086  547.0         0.258
#  3        AUG A3           43      0.086  502.0         0.257
#  4          M416           43      0.086  502.0         0.257
#  5          G36C           43      0.086  502.0         0.257
#  6        QBZ 95           43      0.096  466.0         0.277
#  7        Scar-L           43      0.096  448.0         0.288
#  8         M16A4           43      0.100  430.0         0.300
#  9   Mk47 Mutant           49      0.100  490.0         0.300
#  10          AKM           49      0.100  490.0         0.300
#  11        DP-28           51      0.109  468.0         0.327
#
#      Shots to Kill (Chest)  Shots to Kill (Head)
#  0                       4                     2
#  1                       4                     2
#  2                       4                     2
#  3                       4                     2
#  4                       4                     2
#  5                       4                     2
#  6                       4                     2
#  7                       4                     2
#  8                       4                     2
#  9                       4                     2
#  10                      4                     2
#  11                      4                     2  ,
#        Weapon  Base Damage  Fire Rate  DPS  Time to Kill  \
#  0     Vector           31     0.0545  569         0.273
#  1        UZI           26     0.0480  542         0.288
#  2       MP5K           33     0.0660  495         0.333
#  3  Tommy Gun           40     0.0860  467         0.343
#  4      Bizon           35     0.0860  408         0.343
#  5      UMP45           39     0.0920  423         0.369
#
#     Shots to Kill (Chest)  Shots to Kill (Head)
#  0                      5                     3
#  1                      7                     4
#  2                      5                     3
#  3                      5                     3
#  4                      5                     3
#  5                      5                     3  ,
#    Weapon  Base Damage  Fire Rate   DPS  Time to Kill  Shots to Kill (Chest)  \
#  0   S686          216       0.20  1080             0                      1
#  1  S1897          216       0.75   288             0                      1
#  2   S12k          198       0.25   792             0                      1
#
#     Shots to Kill (Head)
#  0                     1
#  1                     1
#  2                     1  ,
#        Weapon  Base Damage  Fire Rate    DPS  Time to Kill  \
#  0  Sawed-off          160       0.25  640.0         0.250
#  1      R1895           55       0.40  137.5         1.200
#  2        R45           55       0.25  220.0         0.750
#  3      P1911           41       0.11  373.0         0.440
#  4        P92           35       0.14  259.0         0.540
#  5       P18C           23       0.06  383.0         0.420
#  6   Skorpion           22       0.07  312.0         0.494
#
#     Shots to Kill (Chest)  Shots to Kill (Head)
#  0                      2                     1
#  1                      4                     2
#  2                      4                     2
#  3                      5                     3
#  4                      5                     3
#  5                      8                     4
#  6                      8                     4  ,
#             Weapon  Base Damage  Fire Rate  DPS  Time to Kill  \
#  0        Crossbow          105       3.80   28          3.80
#  1             Pan           80       0.75  107          1.50
#  2         Machete           60       0.75   80          1.50
#  3         Crowbar           60       0.75   80          1.50
#  4          Sickle           60       0.75   80          1.50
#  5  Superman Punch           38       1.00   38          4.00
#  6           Punch           18       0.33   55          2.97
#
#     Shots to Kill (Chest)  Shots to Kill (Head)
#  0                      2                     1
#  1                      3                     1
#  2                      3                     2
#  3                      3                     2
#  4                      3                     2
#  5                      5                     2
#  6                     10                     4  ]

# %%
import requests as r
from bs4 import BeautifulSoup as bs
url=r'https://www.eurogamer.net/articles/2019-03-20-pubg-weapon-damage-stats-best-weapons-5414'
pubg_data=r.get(url)

soup=bs(pubg_data.content,'html.parser')
results=soup.find_all('strong',string=lambda text:'damage stats:' in text.lower())

# %%
soup.find
weapon_type=[]
for w_t in results:
    group= w_t.text.strip('</strong>')[0:-14]
    print(group)
    weapon_type.append(group)
# Out:
# Sniper Rifle
# DMR
# Assault Rifles and LMG
# SMG
# Shotgun
# Pistols and Sidearm
# Melee and Other weapon

# %%
pubg=pd.DataFrame()
for i,w_type in enumerate(weapons):
    w_type['Weapon type']=weapon_type[i]
    pubg=pubg.append(w_type,ignore_index=True)
pubg
# Out:
#             Weapon  Base Damage  Fire Rate     DPS  Time to Kill  \
# 0              AWM          105     1.8500    65.0         1.850
# 1              M24           79     1.8000    44.0         1.800
# 2           Kar98k           75     1.9000    39.0         3.800
# 3            Win94           66     0.6000   110.0         1.200
# 4             MK14           61     0.0900   678.0         0.180
# 5              SLR           58     0.1000   580.0         0.200
# 6              SKS           53     0.1000   530.0         0.200
# 7            QBU88           48     0.1000   480.0         0.300
# 8          Mini 14           46     0.1000   460.0         0.300
# 9              VSS           41     0.0900   479.0         0.257
# 10            M249           45     0.0750   600.0         0.225
# 11           Groza           49     0.0800   612.5         0.240
# 12      Beryl M762           47     0.0860   547.0         0.258
# 13          AUG A3           43     0.0860   502.0         0.257
# 14            M416           43     0.0860   502.0         0.257
# 15            G36C           43     0.0860   502.0         0.257
# 16          QBZ 95           43     0.0960   466.0         0.277
# 17          Scar-L           43     0.0960   448.0         0.288
# 18           M16A4           43     0.1000   430.0         0.300
# 19     Mk47 Mutant           49     0.1000   490.0         0.300
# 20             AKM           49     0.1000   490.0         0.300
# 21           DP-28           51     0.1090   468.0         0.327
# 22          Vector           31     0.0545   569.0         0.273
# 23             UZI           26     0.0480   542.0         0.288
# 24            MP5K           33     0.0660   495.0         0.333
# 25       Tommy Gun           40     0.0860   467.0         0.343
# 26           Bizon           35     0.0860   408.0         0.343
# 27           UMP45           39     0.0920   423.0         0.369
# 28            S686          216     0.2000  1080.0         0.000
# 29           S1897          216     0.7500   288.0         0.000
# 30            S12k          198     0.2500   792.0         0.000
# 31       Sawed-off          160     0.2500   640.0         0.250
# 32           R1895           55     0.4000   137.5         1.200
# 33             R45           55     0.2500   220.0         0.750
# 34           P1911           41     0.1100   373.0         0.440
# 35             P92           35     0.1400   259.0         0.540
# 36            P18C           23     0.0600   383.0         0.420
# 37        Skorpion           22     0.0700   312.0         0.494
# 38        Crossbow          105     3.8000    28.0         3.800
# 39             Pan           80     0.7500   107.0         1.500
# 40         Machete           60     0.7500    80.0         1.500
# 41         Crowbar           60     0.7500    80.0         1.500
# 42          Sickle           60     0.7500    80.0         1.500
# 43  Superman Punch           38     1.0000    38.0         4.000
# 44           Punch           18     0.3300    55.0         2.970
#
#     Shots to Kill (Chest)  Shots to Kill (Head)             Weapon type
# 0                       2                     1            Sniper Rifle
# 1                       2                     1            Sniper Rifle
# 2                       2                     1            Sniper Rifle
# 3                       2                     2            Sniper Rifle
# 4                       3                     2                     DMR
# 5                       3                     2                     DMR
# 6                       3                     2                     DMR
# 7                       4                     2                     DMR
# 8                       4                     2                     DMR
# 9                       4                     2                     DMR
# 10                      4                     2  Assault Rifles and LMG
# 11                      4                     2  Assault Rifles and LMG
# 12                      4                     2  Assault Rifles and LMG
# 13                      4                     2  Assault Rifles and LMG
# 14                      4                     2  Assault Rifles and LMG
# 15                      4                     2  Assault Rifles and LMG
# 16                      4                     2  Assault Rifles and LMG
# 17                      4                     2  Assault Rifles and LMG
# 18                      4                     2  Assault Rifles and LMG
# 19                      4                     2  Assault Rifles and LMG
# 20                      4                     2  Assault Rifles and LMG
# 21                      4                     2  Assault Rifles and LMG
# 22                      5                     3                     SMG
# 23                      7                     4                     SMG
# 24                      5                     3                     SMG
# 25                      5                     3                     SMG
# 26                      5                     3                     SMG
# 27                      5                     3                     SMG
# 28                      1                     1                 Shotgun
# 29                      1                     1                 Shotgun
# 30                      1                     1                 Shotgun
# 31                      2                     1     Pistols and Sidearm
# 32                      4                     2     Pistols and Sidearm
# 33                      4                     2     Pistols and Sidearm
# 34                      5                     3     Pistols and Sidearm
# 35                      5                     3     Pistols and Sidearm
# 36                      8                     4     Pistols and Sidearm
# 37                      8                     4     Pistols and Sidearm
# 38                      2                     1  Melee and Other weapon
# 39                      3                     1  Melee and Other weapon
# 40                      3                     2  Melee and Other weapon
# 41                      3                     2  Melee and Other weapon
# 42                      3                     2  Melee and Other weapon
# 43                      5                     2  Melee and Other weapon
# 44                     10                     4  Melee and Other weapon

# %%
df2=pd.read_html('https://www.rockpapershotgun.com/2020/03/10/pubg-guns-weapons-update-6-2-pubg-gun-stats-best-weapons-in-season-6/')

df2[0]=df2[0].drop(columns='Pellets')

# %%
pubg_1=pd.DataFrame()
for df in df2[:7]:
    df=df.drop(columns=['Body DMG','Head DMG','Fire Rate'])

    df.columns=['Weapon','Ammo', 'Mag Size','Reload']

#     pubg.join(df)
    pubg_1=pubg_1.append(df,ignore_index=True)
            
# pubg=pubg.join(pubg_1,how='inner',on='Weapon')
# pubg=pd.concat([pubg,pubg_1],join='inner',keys='Weapon',axis=0)


pubg_1
# Out:
#          Weapon  Ammo      Mag Size Reload
# 0   DBS Shotgun   12G            14     6s
# 1          S12K   12G    5 (Ext: 8)     3s
# 2          S686   12G             2   2.4s
# 3         S1897   12G             5   5.8s
# 4     Sawed-Off   12G             2     4s
# 5        Aug A3  5.56  30 (Ext: 40)  3.67s
# 6          G36C  5.56  30 (Ext: 40)   3.8s
# 7          M416  5.56  30 (Ext: 40)  2.73s
# 8         M16A4  5.56  30 (Ext: 40)  2.86s
# 9         QBZ95  5.56  30 (Ext: 40)  3.66s
# 10       SCAR-L  5.56  30 (Ext: 40)  2.86s
# 11          AKM  7.62  30 (Ext: 40)  3.22s
# 12   Beryl M762  7.62  30 (Ext: 40)   2.9s
# 13        Groza  7.62  30 (Ext: 40)     3s
# 14  MK47 Mutant  7.62  20 (Ext: 30)  3.37s
# 15        Bizon   9mm            53   3.8s
# 16    Micro Uzi   9mm  25 (Ext: 35)   3.1s
# 17         MP5K   9mm  30 (Ext: 40)   2.2s
# 18       Vector   9mm  19 (Ext: 33)   2.2s
# 19    Tommy Gun  0.45  30 (Ext: 50)  3.45s
# 20        UMP45  0.45  25 (Ext: 35)   3.1s
# 21        DP-28  7.62            47   5.5s
# 22         M249  5.56           100   8.2s
# 23          VSS   9mm  10 (Ext: 20)   2.9s
# 24      Mini-14  5.56  20 (Ext: 30)   3.6s
# 25          QBU  5.56  10 (Ext: 20)     3s
# 26      MK14 EB  7.62  10 (Ext: 20)  3.68s
# 27          SLR  7.62  10 (Ext: 20)  3.68s
# 28          SKS  7.62  10 (Ext: 20)   2.9s
# 29        Win94  0.45             8     4s
# 30       Kar98K  7.62             5     4s
# 31          M24  7.62    5 (Ext: 7)   4.2s
# 32          AWM   0.3    5 (Ext: 7)   4.6s
# 33     Crossbow  Bolt             1  3.55s

# %%
def join_df(df1,df2):
    new_df=pd.DataFrame()
    #write to func to dd both datasets
# Out:
# dtype('O')
